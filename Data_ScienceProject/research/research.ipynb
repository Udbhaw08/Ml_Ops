# %%
example={"key1":"vaule1","key2":"vaule2","key3":"vaule3"}

# %%
from box import ConfigBox

# %%
example=ConfigBox({"key1":"vaule1","key2":"vaule2","key3":"vaule3"})

example.key1
# Out:
# 'vaule1'

# %%
##example is for ensure annnoation 

def get_product (x:int, y:int) -> int:
    return x*y

# %%
get_product(2,"4")
# Out:
# '44'

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_product (x:int, y:int) -> int:
    return x*y

# %%
get_product(2,"4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_product(2,"4")
#
# File e:\Udbhaw_Work\Udbhaw_Work\ML_OPS_UDEMY\.venv\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x0000028229FC0680> does not match annotation type <class 'int'>
